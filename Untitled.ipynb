# %% [markdown]
# # (Easy) Running Sum of 1d Array

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
    def runningSum(self, nums: List[int]) -> List[int]:
        cum_sum = 0 #cummulative sum
        for i in range(len(nums)):
            cum_sum += nums[i]
            nums[i] = cum_sum
        return nums
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b82881e6c188> in <module>
# ----> 1 def runningSum(self, nums: List[int]) -> List[int]:
#       2     cum_sum = 0 #cummulative sum
#       3     for i in range(len(nums)):
#       4         cum_sum += nums[i]
#       5         nums[i] = cum_sum
#
# NameError: name 'List' is not defined
